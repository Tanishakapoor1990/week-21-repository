# %% [markdown]
# Make sure you can get the API from class to work in Azure. Take a screenshot of it
# working and add the image to a jupyter notebook.

# %% [markdown]
# PFB screenshots for my working API :

# %% [markdown]
# ![gdp%20url%20.PNG](attachment:gdp%20url%20.PNG)

# %% [markdown]
# ![gdp_url.PNG](attachment:gdp_url.PNG)

# %% [markdown]
# ![hello%20world.PNG](attachment:hello%20world.PNG)

# %% [markdown]
# ![git%20commnads.png](attachment:git%20commnads.png)

# %% [markdown]
# ![git%20commnads1.PNG](attachment:git%20commnads1.PNG)
