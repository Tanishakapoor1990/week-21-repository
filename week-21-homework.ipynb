# %% [markdown]
# 1.	Create a basic API in Azure (as we did in class) that tells you how to access the different
# endpoints when you go to the home page. You should have the following endpoints:

# %% [markdown]
# screenshots of code working locally

# %% [markdown]
# ![Screenshot%202021-07-27%20220157.png](attachment:Screenshot%202021-07-27%20220157.png)

# %% [markdown]
# ![Screenshot%202021-07-27%20220249.png](attachment:Screenshot%202021-07-27%20220249.png)

# %% [markdown]
# ![Screenshot%202021-07-27%20220749.png](attachment:Screenshot%202021-07-27%20220749.png)

# %% [markdown]
# ## You can see the code for the same in flask-app2.py file

# %% [markdown]
# ## screenshots for code working on azure

# %% [markdown]
# ![azure.PNG](attachment:azure.PNG)

# %% [markdown]
# ![azure1.PNG](attachment:azure1.PNG)

# %% [markdown]
# ![azure2.PNG](attachment:azure2.PNG)

# %% [markdown]
# You can check the following file for code

# %% [markdown]
# https://github.com/Tanishakapoor1990/week-21-repository/blob/master/flask_app/flask-app2.py
#
# https://github.com/Tanishakapoor1990/week-21-repository/blob/master/flask_app/templates/user_nobel.html

# %% [markdown]
# 2.	What kind of API did you build? What types of APIs are there? Why are APIs important?

# %% [markdown]
# ### API overview :
#
# An API (Application Programming Interface) is a set of functions that allows applications to access data and interact with external software components, operating systems, or microservices. To simplify, an API delivers a user response to a system and sends the system's response back to a user.
#
# ### I have build a REST API.
#
# ### Types of API :
#
#     1)SOAP
#
#     2)REST
#
#     3)RPC(Remote Procedure Call)
#
#     4)GraphQL
#
#
# ### API Importance:
#  APIs, or application program interfaces, are vital tools for businesses in all industries. The importance of APIs from a technical standpoint, they allow the capabilities of one computer program to be used by another. They are a means by which two different programs are able to communicate.
